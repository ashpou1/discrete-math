# %% [markdown]
# <a href="https://colab.research.google.com/github/ashpou1/discrete-math/blob/main/Graph%26Numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #3 : CPSMA 3133 Discrete Mathematics
# ## ASHOK SHARMA POUDEL
# ##GRAPH AND NUMBERS

# %% [markdown]
# ##**Graph**

# %% [markdown]
# Family of peaky blinders.
# polly is aunty of Thomas, Jhon, Author and Finn. Michale is the son of Polly.
# Thomas, Jhon, Author and Finn are 4 brothers

# %%
import graphviz

# %%
dot = graphviz.Digraph(comment='PEAKY BLINDERS')
dot.node('A', 'Thomas')
dot.node('B', 'John')
dot.node('C', 'Author')
dot.node('D', 'Finn')
dot.node('E', 'Polly')
dot.node('F', 'Michale')

dot.edges(['AB', 'AC','AD', 'EA','EB', 'EC', 'ED', 'EF', 'BD', 'BC', 'CD'])
dot

# %% [markdown]
# ##PATH OF GRAPH
# POLLY - MICHALE
#
# POLLY - THOMAS
#
# POLLY - AUTHOR
#
# POLLY - JHON
#
# POLLY - FINN
#
# THOMAS - AUTHOR
#
# THOMAS - JHON
#
# THOMAS - FINN
#
# JHON - AUTHOR
#
# AUTHOR - FINN
#
# JHON - FINN

# %% [markdown]
# ##DEGREE OF VERTICES
# POLLY = 5
#
# THOMAS = 4
#
# AUTHOR = 4
#
# JHON = 4
#
# FINN = 4
#
# MICHALE = 1

# %% [markdown]
# ##CYCLE

# %% [markdown]
# There is path exist which will be $Polly$ to $Thomas$ to $Author$ to $Finn$ to $John$ to $Polly$

# %% [markdown]
# ## NUMBERS

# %% [markdown]
# we have 24036 base of 7 to base of 10

# %%
(2*(7^4))+(4*(7^3))+(0*(7^2))+(3*(7^1))+(6*(7^0))
# Out:
# 82

# %% [markdown]
# ##24036 base of 7 is 82 base of 10

# %% [markdown]
# Hexadecimal number 72e3 to base 10

# %%
(7*(16^3))+(2*(16^2))+(15*(16^1))+(3*(16^0))
# Out:
# 472

# %% [markdown]
# ##Hexadecimal number 72e3 is 472 in the base of 10

# %% [markdown]
# 3735928559 into hexadecimal.

# %%
from math import floor

# %%
print(3735928559%16)
floor(3735928559/16)
# Out:
# 15
# 233495534

# %%
print(233495534%16)
floor(233495534/16)
# Out:
# 14
# 14593470

# %%
print(14593470%16)
floor(14593470/16)
# Out:
# 14
# 912091

# %%
print(912091%16)
floor(912091/16)
# Out:
# 11
# 57005

# %%
print(57005%16)
floor(57005/16)
# Out:
# 13
# 3562

# %%
print(3562%16)
floor(3562/16)
# Out:
# 10
# 222

# %%
print(222%16)
floor(222/16)
# Out:
# 14
# 13

# %%
print(13%16)
floor(13/16)
# Out:
# 13
# 0

# %% [markdown]
# # Finally, the numbers are 13 as $d$, 14 as $e$, 10 as $a$, 13 as $d$, 11 as $b$, 14 as $e$, 14 as $e$ and 15 as $f$ which will be  $deadbeef$ as my hexadecimal of 3735928559

# %% [markdown]
# lets do double check if it my number in hexadecimal is right or wrong:

# %%
hex(3735928559)
# Out:
# '0xdeadbeef'

# %% [markdown]
# Note: I got '0x' for my Hexadecimal representation in python

# %% [markdown]
# Using two’s complement preform the base ten subtraction 25 − 37. Check your answer.

# %%
int('11001',2)
# Out:
# 25

# %%
int('100101',2)
# Out:
# 37

# %% [markdown]
# in base of 10, subtraction of

# %%
25-37
# Out:
# -12

# %% [markdown]
# lets check if -1100 is right number

# %%
int('-1100',2)
# Out:
# -12

# %% [markdown]
# So, we got same answers. Using two’s complement preform the base ten subtraction 25(11001) − 37(100101) comes to -1100
